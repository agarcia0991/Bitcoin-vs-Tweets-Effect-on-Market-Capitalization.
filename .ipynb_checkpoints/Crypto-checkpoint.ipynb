# %%
# Imports 
import csv
import pandas as pd
from pyspark.sql import SparkSession

# %%
bitcoin_path = "Resources/coin_Bitcoin.csv"
# tweets_path = "Resources/Bitcoin_tweets.csv"

# Read World Happiness Data Using File Path
bitcoin_df = pd.read_csv(bitcoin_path)
#tweets_data = pd.read_csv(tweets_path)

# %%
bitcoin_df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
# tweets_df.head(10)

# %%
bitcoin_df = bitcoin_df.drop(columns = ["SNo","Name","Symbol"])

# %%
bitcoin_df.head()
# Out:
#                   Date        High         Low        Open       Close  \
# 0  2013-04-29 23:59:59  147.488007  134.000000  134.444000  144.539993
# 1  2013-04-30 23:59:59  146.929993  134.050003  144.000000  139.000000
# 2  2013-05-01 23:59:59  139.889999  107.720001  139.000000  116.989998
# 3  2013-05-02 23:59:59  125.599998   92.281898  116.379997  105.209999
# 4  2013-05-03 23:59:59  108.127998   79.099998  106.250000   97.750000
#
#    Volume     Marketcap
# 0     0.0  1.603769e+09
# 1     0.0  1.542813e+09
# 2     0.0  1.298955e+09
# 3     0.0  1.168517e+09
# 4     0.0  1.085995e+09

# %%
spark = SparkSession.builder.appName("read_csv").getOrCreate()
tweets_data = spark.read.csv("Resources/Bitcoin_tweets.csv",sep = ",",inferSchema = True, header = True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14392/2525811273.py in <module>
# ----> 1 spark = SparkSession.builder.appName("read_csv").getOrCreate()
#       2 tweets_data = spark.read.csv("Resources/Bitcoin_tweets.csv",sep = ",",inferSchema = True, header = True)
#
# ~\anaconda3\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# ~\anaconda3\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     390         with SparkContext._lock:
# ...
